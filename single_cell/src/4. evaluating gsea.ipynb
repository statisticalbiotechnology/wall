# %%
import pandas as pd
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
gsea = pd.read_csv("GSEA_/single_cell/gseapy.gsea.gene_set.report.csv", index_col = 0)
gsea.sort_values(by="fdr", ascending = True).iloc[:10]
#printing top 10 pathways
# Out:
#                                                           es         nes  \
# Term
# Class A/1 (Rhodopsin-like receptors) Homo sapie... -0.182625         inf
# Nonsense Mediated Decay (NMD) enhanced by the E... -0.407433 -111.085108
# 3' -UTR-mediated translational regulation Homo ... -0.410033 -111.109409
# PIP3 activates AKT signaling Homo sapiens R-HSA... -0.291429 -101.503470
# Eukaryotic Translation Elongation Homo sapiens ... -0.440484 -112.939372
# Muscle contraction Homo sapiens R-HSA-397014       -0.267688 -275.387027
# GAB1 signalosome Homo sapiens R-HSA-180292         -0.279009  -92.067412
# Cap-dependent Translation Initiation Homo sapie... -0.393730 -115.199425
# PI3K/AKT activation Homo sapiens R-HSA-198203      -0.284155  -94.763550
# L13a-mediated translational silencing of Cerulo... -0.410033  -93.278455
#
#                                                         pval       fdr  \
# Term
# Class A/1 (Rhodopsin-like receptors) Homo sapie...       NaN  0.000000
# ...
