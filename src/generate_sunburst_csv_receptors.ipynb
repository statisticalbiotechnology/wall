# %%
import pandas as pd
from ast import literal_eval
import numpy as np
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
from statistics import mean, median
import scipy
from sklearn.decomposition import PCA
from sklearn import preprocessing
from gprofiler import GProfiler
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
import operator
import qvalue as qv


#Reactome file containing information on pathways, the genes they contain and pathway name, also including the illumina identifier for the genes.

reactome = pd.read_csv('../data/reactome.csv', sep=',', index_col = 0)

def read_reactome(file_name, gene_name_start = "ENSG0"):
    df = pd.read_csv(file_name, sep='\t', header=None)
    
    if gene_name_start == None:
        sub_df = df
    else:
        subset_vec = df[0].str.startswith(gene_name_start)
        sub_df = df.loc[subset_vec]
    
    genes_df = sub_df.groupby(1)[0].apply(list)
    names_df = sub_df.groupby(1)[3].max()
    
    out_df = pd.concat([genes_df,names_df], axis=1)
    out_df.columns = ['genes', 'pathway_name']
    
    return out_df

low_level = read_reactome('../data/Ensembl2Reactome_All_Levels.txt')

def my_pca(df, n_pc=1, normalize=True):
    df = df.dropna(axis = 0, how = 'all')#redundant, but keeping it just in case
    X = df.values.T
    if normalize:
        X2 = preprocessing.scale(X)
    else:
        X2 = X
    pca = PCA(n_components = n_pc)
    pca.fit(X2)
    my_pca.pca = pca  #needed for components
    Xnew = pca.fit_transform(X2)
    out_df = pd.DataFrame(Xnew.transpose(), index=list(range(1,n_pc+1)), columns=df.columns)
    out_df = out_df.transpose()
    
    return out_df, my_pca.pca.components_, my_pca.pca.explained_variance_ratio_

#Importing metabric dataset, dividing up what is clinical/expression data and changing the type of the expression columns to float
metabric_data = pd.read_csv('../data/metabric.csv')
#clinical_data = metabric_data.iloc[:27, :]
expression_data = metabric_data.iloc[27:,:]

#print(expression_data.columns)
dtypedict = {}
for i in expression_data.columns[1:]:
    dtypedict[i] = 'float32'
expression_data = expression_data.astype(dtypedict)



new_clinical_patient = pd.read_csv('../data/brca_metabric/data_clinical_patient.txt', sep='\t', index_col=0).iloc[4:]
new_clinical_sample = pd.read_csv('../data/brca_metabric/data_clinical_sample.txt', sep='\t', index_col=0).iloc[4:]
new_clinical = pd.concat([new_clinical_patient, new_clinical_sample.reindex(new_clinical_patient.index)], axis=1)
new_clinical['Triple Neg'] = new_clinical.apply(lambda row: True if ((row['ER Status'] == 'Negative') 
                                                                     and (row['PR Status'] == 'Negative') 
                                                                     and (row['HER2 Status'] == 'Negative')) else False, axis = 1)

new_clinical['ER-/PR-/HER2+'] = new_clinical.apply(lambda row: True if ((row['ER Status'] == 'Negative') 
                                                                     and (row['PR Status'] == 'Negative') 
                                                                     and (row['HER2 Status'] == 'Positive')) else False, axis = 1)





genes = expression_data['Unnamed: 0'].values.tolist()

gp = GProfiler(return_dataframe = True)
gp = gp.convert(organism='hsapiens',
          query=genes)

gp = gp.loc[gp['n_converted'] == 1]
gp = gp.loc[gp['name'] != 'None']
gp = gp.set_index('incoming')
gprofiler_names = gp
gprofiler_names

dataset = expression_data.set_index('Unnamed: 0') #gene_patient
pca_per_pathway = pd.DataFrame(index=expression_data.columns)

real_gene_names = pd.read_csv('../data/illumina2symbol.txt', sep="\t", index_col = 0)



genes_components_per_pathway = {} #nested dictionary where the 'outer dictionary' is the pathway names as keys and values are 
                                  #another dictionary with genes as keys and components as values

for pathway in reactome.index:
    genes = reactome.loc[pathway, "illumina"]
    genes = literal_eval(genes)
    genes = list(filter(lambda a: a != 'NaN', genes))
    pathwaydata = dataset.loc[genes]
    if pathwaydata.index.empty == True:
        pass
    else:
        pathwaydata = pathwaydata.dropna(axis = 0, how = 'any') #has to be done so the lists match, this makes the dropna in my_pca function obsolete
        presentgenes = pathwaydata.index.values.tolist()
        if len(presentgenes) <= 1:
            pass
        else:
            res, components, explained_variance = my_pca(pathwaydata)
            pathwayname = reactome.loc[pathway, 'pathway_name']
            pca_per_pathway[pathwayname] = res

            components = components.tolist()[0]
            innerdict = {}
            for i in range(0, len(presentgenes)):
                component = components[i]
                gene = genes[i]
                if gene in real_gene_names.index:
                    real_name = real_gene_names.loc[gene, "symbol"]
                    innerdict[real_name] = component
                elif gene in gprofiler_names.index:
                    real_name = gprofiler_names.loc[gene, 'name']
                    innerdict[real_name] = component
                else:
                    innerdict[gene] = component
            sorted_innerdict = sorted(innerdict.items(), key = operator.itemgetter(1), reverse = True)
            genes_components_per_pathway[pathwayname] = [sorted_innerdict, explained_variance.flat[0]]

pca_per_pathway = pca_per_pathway.iloc[1:]
# Out:
# <style>.container { width:100% !important; }</style>

# %%
full_df = pd.concat([pca_per_pathway, new_clinical.reindex(pca_per_pathway.index)], axis=1)

# %%
from scipy.stats import ttest_ind, mannwhitneyu
import qvalue as qv

clusterframes = {}
receptor_list = ['ER Status', 'PR Status', 'HER2 Status', 'Triple Neg', 'ER-/PR-/HER2+']

for i in receptor_list:
    grouped_by_receptor = full_df.groupby(i)
    for group in grouped_by_receptor:
        #print(group)
        df_cluster = pd.DataFrame(index=full_df.iloc[:,:-33].columns)
        groupname = group[0]
        print(f'{i} == {groupname}')
        df = group[1].iloc[:,:-33]
        group2_df = full_df[full_df[i] != groupname].iloc[:,:-33]
        pvaluelist = []
        group1_mean_list = []
        group2_mean_list = []
        for pathway in df:
            group = df[pathway]
            #print(group)
            group2 = group2_df[pathway]
            test = mannwhitneyu(group, group2)
            #print(test)
            pvaluelist.append(test[1])
            group_mean = group.mean()
            group1_mean_list.append(group_mean)
            group2_mean = group2.mean()
            group2_mean_list.append(group2_mean) 
        
    
        #df_cluster[f'Cluster {groupname}'] = group1_mean_list
        #df_cluster['Other clusters'] = group2_mean_list
        #df_cluster['Fold Change'] = np.log2(abs(df_cluster[f'Cluster {groupname}'])) - np.log2(abs(df_cluster['Other clusters']))
    
        df_cluster['p-values'] = pvaluelist
        qv.qvalues(df_cluster, 'p-values', f'{i} qvalues')
        df_cluster['p-values'] = -np.log10(df_cluster['p-values'])
        df_cluster[f'{i} qvalues'] = -np.log10(df_cluster[f'{i} qvalues'])
        #print(groupname)
    clusterframes[f'{i}'] = df_cluster
        
        
#clusterframes
# Out:
# ER Status == Negative
# ER Status == Positive
# PR Status == Negative
# PR Status == Positive
# HER2 Status == Negative
# HER2 Status == Positive
# Triple Neg == False
# Triple Neg == True
# ER-/PR-/HER2+ == False
# ER-/PR-/HER2+ == True

# %%
clusterframes['ER Status']
# Out:
#                                                       p-values  \
# RUNX1 regulates estrogen receptor mediated tran...  224.472619
# Activation of AMPK downstream of NMDARs             198.176334
# Transcriptional Regulation by MECP2                 190.702842
# SLC-mediated transmembrane transport                188.588305
# DAG and IP3 signaling                               188.497798
# PLC beta mediated events                            186.894359
# G-protein mediated events                           186.418710
# Caspase-mediated cleavage of cytoskeletal proteins  182.790808
# TFAP2 (AP-2) family regulates transcription of ...  181.851836
# Cyclin D associated events in G1                    175.338235
# G1 Phase                                            175.338235
# Estrogen-dependent nuclear events downstream of...  172.302000
# Ion channel transport                               172.022669
# Reversible hydration of carbon dioxide              171.948441
# Amino acid transport across the plasma membrane     171.945117
# Transport of inorganic cations/anions and amino...  170.313991
# PKA-mediated phosphorylation of CREB                169.339732
# Serine biosynthesis                                 169.206747
# Ca-dependent events                                 168.639130
# CaM pathway                                         168.453793
# Calmodulin induced events                           168.447215
# Cardiac conduction                                  168.377056
# ABC transporters in lipid homeostasis               167.967360
# Post NMDA receptor activation events                163.419363
# Activation of NMDA receptors and postsynaptic e...  163.168960
# Intraflagellar transport                            160.903675
# Fatty acid metabolism                               158.297118
# Signaling by ERBB4                                  157.028866
# Transport of bile salts and organic acids, meta...  156.179184
# MECP2 regulates neuronal receptors and channels     153.518493
# ...                                                        ...
# Regulation of commissural axon pathfinding by S...    0.391770
# Diseases associated with glycosaminoglycan meta...    0.389659
# Mitochondrial Fatty Acid Beta-Oxidation               0.383035
# Proline catabolism                                    0.374323
# MECP2 regulates transcription of neuronal ligands     0.367046
# Post-translational protein phosphorylation            0.361759
# Eicosanoid ligand-binding receptors                   0.361186
# SMAC, XIAP-regulated apoptotic response               0.358370
# Biosynthesis of maresin-like SPMs                     0.356028
# Syndecan interactions                                 0.351517
# Cation-coupled Chloride cotransporters                0.350745
# Synthesis of GDP-mannose                              0.349381
# Defective B3GALT6 causes EDSP2 and SEMDJL1            0.347497
# Golgi Associated Vesicle Biogenesis                   0.347462
# Membrane Trafficking                                  0.346245
# Organic anion transporters                            0.342026
# Defective B4GALT7 causes EDS, progeroid type          0.339347
# PI-3K cascade:FGFR1                                   0.337296
# Leukotriene receptors                                 0.335321
# Collagen degradation                                  0.335049
# Activated NTRK2 signals through PI3K                  0.334845
# Scavenging by Class H Receptors                       0.322944
# G-protein activation                                  0.321489
# CYP2E1 reactions                                      0.318266
# cGMP effects                                          0.315033
# CS/DS degradation                                     0.306297
# Regulation of FZD by ubiquitination                   0.305404
# Chondroitin sulfate biosynthesis                      0.305341
# Defective MTRR causes methylmalonic aciduria an...    0.302230
# Defective MTR causes methylmalonic aciduria and...    0.302230
#
#                                                     ER Status qvalues
# RUNX1 regulates estrogen receptor mediated tran...         221.155811
# Activation of AMPK downstream of NMDARs                    195.160555
# Transcriptional Regulation by MECP2                        187.863154
# SLC-mediated transmembrane transport                       185.879960
# DAG and IP3 signaling                                      185.879960
# PLC beta mediated events                                   184.355702
# G-protein mediated events                                  183.946999
# Caspase-mediated cleavage of cytoskeletal proteins         180.377089
# TFAP2 (AP-2) family regulates transcription of ...         179.489270
# Cyclin D associated events in G1                           173.062819
# G1 Phase                                                   173.062819
# Estrogen-dependent nuclear events downstream of...         170.064372
# Ion channel transport                                      169.819803
# Reversible hydration of carbon dioxide                     169.804400
# Amino acid transport across the plasma membrane            169.804400
# Transport of inorganic cations/anions and amino...         168.201302
# PKA-mediated phosphorylation of CREB                       167.253372
# Serine biosynthesis                                        167.145211
# Ca-dependent events                                        166.601075
# CaM pathway                                                166.452625
# Calmodulin induced events                                  166.452625
# Cardiac conduction                                         166.402670
# ABC transporters in lipid homeostasis                      166.012279
# Post NMDA receptor activation events                       161.482766
# Activation of NMDA receptors and postsynaptic e...         161.250091
# Intraflagellar transport                                   159.001840
# Fatty acid metabolism                                      156.411673
# Signaling by ERBB4                                         155.159215
# Transport of bile salts and organic acids, meta...         154.324773
# MECP2 regulates neuronal receptors and channels            151.678805
# ...                                                               ...
# Regulation of commissural axon pathfinding by S...           0.385655
# Diseases associated with glycosaminoglycan meta...           0.383755
# Mitochondrial Fatty Acid Beta-Oxidation                      0.377344
# Proline catabolism                                           0.368844
# MECP2 regulates transcription of neuronal ligands            0.361779
# Post-translational protein phosphorylation                   0.356704
# Eicosanoid ligand-binding receptors                          0.356343
# SMAC, XIAP-regulated apoptotic response                      0.353738
# Biosynthesis of maresin-like SPMs                            0.351608
# Syndecan interactions                                        0.347309
# Cation-coupled Chloride cotransporters                       0.346748
# Synthesis of GDP-mannose                                     0.345595
# Defective B3GALT6 causes EDSP2 and SEMDJL1                   0.344099
# Golgi Associated Vesicle Biogenesis                          0.344099
# Membrane Trafficking                                         0.343093
# Organic anion transporters                                   0.339084
# Defective B4GALT7 causes EDS, progeroid type                 0.336616
# PI-3K cascade:FGFR1                                          0.334775
# Leukotriene receptors                                        0.333011
# Collagen degradation                                         0.332957
# Activated NTRK2 signals through PI3K                         0.332957
# Scavenging by Class H Receptors                              0.321266
# G-protein activation                                         0.320021
# CYP2E1 reactions                                             0.317008
# cGMP effects                                                 0.313984
# CS/DS degradation                                            0.305459
# Regulation of FZD by ubiquitination                          0.304922
# Chondroitin sulfate biosynthesis                             0.304922
# Defective MTRR causes methylmalonic aciduria an...           0.302230
# Defective MTR causes methylmalonic aciduria and...           0.302230
#
# [2074 rows x 2 columns]

# %%
full_clusterframe = pd.DataFrame(index=clusterframes['ER Status'].index)
for i in clusterframes:
    series = clusterframes[i][f'{i} qvalues']
    full_clusterframe = pd.concat([full_clusterframe, series.reindex(full_clusterframe.index)], axis=1)

# %%
full_clusterframe
# Out:
#                                                     ER Status qvalues  \
# RUNX1 regulates estrogen receptor mediated tran...         221.155811
# Activation of AMPK downstream of NMDARs                    195.160555
# Transcriptional Regulation by MECP2                        187.863154
# SLC-mediated transmembrane transport                       185.879960
# DAG and IP3 signaling                                      185.879960
# PLC beta mediated events                                   184.355702
# G-protein mediated events                                  183.946999
# Caspase-mediated cleavage of cytoskeletal proteins         180.377089
# TFAP2 (AP-2) family regulates transcription of ...         179.489270
# Cyclin D associated events in G1                           173.062819
# G1 Phase                                                   173.062819
# Estrogen-dependent nuclear events downstream of...         170.064372
# Ion channel transport                                      169.819803
# Reversible hydration of carbon dioxide                     169.804400
# Amino acid transport across the plasma membrane            169.804400
# Transport of inorganic cations/anions and amino...         168.201302
# PKA-mediated phosphorylation of CREB                       167.253372
# Serine biosynthesis                                        167.145211
# Ca-dependent events                                        166.601075
# CaM pathway                                                166.452625
# Calmodulin induced events                                  166.452625
# Cardiac conduction                                         166.402670
# ABC transporters in lipid homeostasis                      166.012279
# Post NMDA receptor activation events                       161.482766
# Activation of NMDA receptors and postsynaptic e...         161.250091
# Intraflagellar transport                                   159.001840
# Fatty acid metabolism                                      156.411673
# Signaling by ERBB4                                         155.159215
# Transport of bile salts and organic acids, meta...         154.324773
# MECP2 regulates neuronal receptors and channels            151.678805
# ...                                                               ...
# Regulation of commissural axon pathfinding by S...           0.385655
# Diseases associated with glycosaminoglycan meta...           0.383755
# Mitochondrial Fatty Acid Beta-Oxidation                      0.377344
# Proline catabolism                                           0.368844
# MECP2 regulates transcription of neuronal ligands            0.361779
# Post-translational protein phosphorylation                   0.356704
# Eicosanoid ligand-binding receptors                          0.356343
# SMAC, XIAP-regulated apoptotic response                      0.353738
# Biosynthesis of maresin-like SPMs                            0.351608
# Syndecan interactions                                        0.347309
# Cation-coupled Chloride cotransporters                       0.346748
# Synthesis of GDP-mannose                                     0.345595
# Defective B3GALT6 causes EDSP2 and SEMDJL1                   0.344099
# Golgi Associated Vesicle Biogenesis                          0.344099
# Membrane Trafficking                                         0.343093
# Organic anion transporters                                   0.339084
# Defective B4GALT7 causes EDS, progeroid type                 0.336616
# PI-3K cascade:FGFR1                                          0.334775
# Leukotriene receptors                                        0.333011
# Collagen degradation                                         0.332957
# Activated NTRK2 signals through PI3K                         0.332957
# Scavenging by Class H Receptors                              0.321266
# G-protein activation                                         0.320021
# CYP2E1 reactions                                             0.317008
# cGMP effects                                                 0.313984
# CS/DS degradation                                            0.305459
# Regulation of FZD by ubiquitination                          0.304922
# Chondroitin sulfate biosynthesis                             0.304922
# Defective MTRR causes methylmalonic aciduria an...           0.302230
# Defective MTR causes methylmalonic aciduria and...           0.302230
#
#                                                     PR Status qvalues  \
# RUNX1 regulates estrogen receptor mediated tran...          84.308190
# Activation of AMPK downstream of NMDARs                    147.006933
# Transcriptional Regulation by MECP2                         87.384574
# SLC-mediated transmembrane transport                        80.252014
# DAG and IP3 signaling                                       99.793291
# PLC beta mediated events                                    99.086586
# G-protein mediated events                                   98.508600
# Caspase-mediated cleavage of cytoskeletal proteins         126.052781
# TFAP2 (AP-2) family regulates transcription of ...          62.279443
# Cyclin D associated events in G1                           101.188964
# G1 Phase                                                   101.188964
# Estrogen-dependent nuclear events downstream of...          74.475788
# Ion channel transport                                       69.083310
# Reversible hydration of carbon dioxide                      74.590574
# Amino acid transport across the plasma membrane             75.659549
# Transport of inorganic cations/anions and amino...          74.757520
# PKA-mediated phosphorylation of CREB                        93.150777
# Serine biosynthesis                                         82.486286
# Ca-dependent events                                         84.232815
# CaM pathway                                                 83.593257
# Calmodulin induced events                                   83.593257
# Cardiac conduction                                          71.705240
# ABC transporters in lipid homeostasis                       72.652151
# Post NMDA receptor activation events                       105.226205
# Activation of NMDA receptors and postsynaptic e...         102.910859
# Intraflagellar transport                                   102.910859
# Fatty acid metabolism                                       88.141137
# Signaling by ERBB4                                          73.052610
# Transport of bile salts and organic acids, meta...          59.330293
# MECP2 regulates neuronal receptors and channels             65.617537
# ...                                                               ...
# Regulation of commissural axon pathfinding by S...           0.669681
# Diseases associated with glycosaminoglycan meta...           1.379620
# Mitochondrial Fatty Acid Beta-Oxidation                      0.966701
# Proline catabolism                                           1.752138
# MECP2 regulates transcription of neuronal ligands            0.639610
# Post-translational protein phosphorylation                   1.566606
# Eicosanoid ligand-binding receptors                          0.706592
# SMAC, XIAP-regulated apoptotic response                      0.469478
# Biosynthesis of maresin-like SPMs                            0.360874
# Syndecan interactions                                        1.162478
# Cation-coupled Chloride cotransporters                       1.398880
# Synthesis of GDP-mannose                                     0.496426
# Defective B3GALT6 causes EDSP2 and SEMDJL1                   0.698140
# Golgi Associated Vesicle Biogenesis                          0.612807
# Membrane Trafficking                                         1.157997
# Organic anion transporters                                   1.308808
# Defective B4GALT7 causes EDS, progeroid type                 0.769402
# PI-3K cascade:FGFR1                                          0.629750
# Leukotriene receptors                                        0.580239
# Collagen degradation                                         0.681676
# Activated NTRK2 signals through PI3K                         8.110172
# Scavenging by Class H Receptors                              1.256928
# G-protein activation                                         1.078295
# CYP2E1 reactions                                             0.397392
# cGMP effects                                                 0.604988
# CS/DS degradation                                            0.355197
# Regulation of FZD by ubiquitination                          0.693511
# Chondroitin sulfate biosynthesis                             0.343306
# Defective MTRR causes methylmalonic aciduria an...           0.442295
# Defective MTR causes methylmalonic aciduria and...           0.442295
#
#                                                     HER2 Status qvalues  \
# RUNX1 regulates estrogen receptor mediated tran...            28.402013
# Activation of AMPK downstream of NMDARs                       34.695046
# Transcriptional Regulation by MECP2                           30.443113
# SLC-mediated transmembrane transport                          19.738374
# DAG and IP3 signaling                                         25.325545
# PLC beta mediated events                                      19.032214
# G-protein mediated events                                     18.186084
# Caspase-mediated cleavage of cytoskeletal proteins            35.521822
# TFAP2 (AP-2) family regulates transcription of ...            17.073205
# Cyclin D associated events in G1                              24.016694
# G1 Phase                                                      24.016694
# Estrogen-dependent nuclear events downstream of...            15.823742
# Ion channel transport                                         13.097169
# Reversible hydration of carbon dioxide                        14.147331
# Amino acid transport across the plasma membrane               19.542623
# Transport of inorganic cations/anions and amino...            15.952068
# PKA-mediated phosphorylation of CREB                          13.451158
# Serine biosynthesis                                           21.865110
# Ca-dependent events                                           11.275734
# CaM pathway                                                   11.034864
# Calmodulin induced events                                     11.034864
# Cardiac conduction                                            16.370975
# ABC transporters in lipid homeostasis                         25.546479
# Post NMDA receptor activation events                          26.533631
# Activation of NMDA receptors and postsynaptic e...            27.378653
# Intraflagellar transport                                      16.088433
# Fatty acid metabolism                                         15.200884
# Signaling by ERBB4                                            11.903263
# Transport of bile salts and organic acids, meta...             8.821209
# MECP2 regulates neuronal receptors and channels               22.027293
# ...                                                                 ...
# Regulation of commissural axon pathfinding by S...             1.439957
# Diseases associated with glycosaminoglycan meta...             0.488322
# Mitochondrial Fatty Acid Beta-Oxidation                        0.485591
# Proline catabolism                                            34.008105
# MECP2 regulates transcription of neuronal ligands              0.627108
# Post-translational protein phosphorylation                     0.584246
# Eicosanoid ligand-binding receptors                            1.112035
# SMAC, XIAP-regulated apoptotic response                        7.522559
# Biosynthesis of maresin-like SPMs                              1.129314
# Syndecan interactions                                          2.797480
# Cation-coupled Chloride cotransporters                         0.910498
# Synthesis of GDP-mannose                                       6.474939
# Defective B3GALT6 causes EDSP2 and SEMDJL1                     2.183838
# Golgi Associated Vesicle Biogenesis                            0.492309
# Membrane Trafficking                                           1.337773
# Organic anion transporters                                     6.111264
# Defective B4GALT7 causes EDS, progeroid type                   2.025922
# PI-3K cascade:FGFR1                                            0.322500
# Leukotriene receptors                                          1.214567
# Collagen degradation                                           1.715985
# Activated NTRK2 signals through PI3K                           8.617737
# Scavenging by Class H Receptors                                0.583873
# G-protein activation                                           1.302107
# CYP2E1 reactions                                               0.727094
# cGMP effects                                                   0.607853
# CS/DS degradation                                              1.021556
# Regulation of FZD by ubiquitination                            1.794534
# Chondroitin sulfate biosynthesis                               0.475961
# Defective MTRR causes methylmalonic aciduria an...             2.891732
# Defective MTR causes methylmalonic aciduria and...             2.891732
#
#                                                     Triple Neg qvalues  \
# RUNX1 regulates estrogen receptor mediated tran...          143.584542
# Activation of AMPK downstream of NMDARs                     140.755584
# Transcriptional Regulation by MECP2                         134.874878
# SLC-mediated transmembrane transport                        145.657094
# DAG and IP3 signaling                                       141.757321
# PLC beta mediated events                                    143.410767
# G-protein mediated events                                   143.584542
# Caspase-mediated cleavage of cytoskeletal proteins          127.279985
# TFAP2 (AP-2) family regulates transcription of ...          129.712769
# Cyclin D associated events in G1                            129.862138
# G1 Phase                                                    129.862138
# Estrogen-dependent nuclear events downstream of...          129.588375
# Ion channel transport                                       135.810515
# Reversible hydration of carbon dioxide                      126.603594
# Amino acid transport across the plasma membrane             137.316724
# Transport of inorganic cations/anions and amino...          135.800202
# PKA-mediated phosphorylation of CREB                        137.362254
# Serine biosynthesis                                         114.389951
# Ca-dependent events                                         137.206274
# CaM pathway                                                 137.055262
# Calmodulin induced events                                   137.055262
# Cardiac conduction                                          135.128332
# ABC transporters in lipid homeostasis                       113.303086
# Post NMDA receptor activation events                        119.606896
# Activation of NMDA receptors and postsynaptic e...          118.719916
# Intraflagellar transport                                    127.027309
# Fatty acid metabolism                                       121.326484
# Signaling by ERBB4                                          117.901343
# Transport of bile salts and organic acids, meta...          130.816588
# MECP2 regulates neuronal receptors and channels             105.795094
# ...                                                                ...
# Regulation of commissural axon pathfinding by S...            0.462717
# Diseases associated with glycosaminoglycan meta...            0.311534
# Mitochondrial Fatty Acid Beta-Oxidation                       0.415581
# Proline catabolism                                           14.897518
# MECP2 regulates transcription of neuronal ligands             0.777631
# Post-translational protein phosphorylation                    0.502536
# Eicosanoid ligand-binding receptors                           0.510718
# SMAC, XIAP-regulated apoptotic response                       2.694275
# Biosynthesis of maresin-like SPMs                             0.323251
# Syndecan interactions                                         1.108363
# Cation-coupled Chloride cotransporters                        1.051150
# Synthesis of GDP-mannose                                      1.751962
# Defective B3GALT6 causes EDSP2 and SEMDJL1                    0.891586
# Golgi Associated Vesicle Biogenesis                           0.831754
# Membrane Trafficking                                          0.924436
# Organic anion transporters                                    1.837638
# Defective B4GALT7 causes EDS, progeroid type                  0.999145
# PI-3K cascade:FGFR1                                           0.317298
# Leukotriene receptors                                         0.412713
# Collagen degradation                                          0.782982
# Activated NTRK2 signals through PI3K                          2.173975
# Scavenging by Class H Receptors                               1.001645
# G-protein activation                                          0.514842
# CYP2E1 reactions                                              0.420865
# cGMP effects                                                  1.408586
# CS/DS degradation                                             0.982557
# Regulation of FZD by ubiquitination                           1.246341
# Chondroitin sulfate biosynthesis                              0.503961
# Defective MTRR causes methylmalonic aciduria an...            1.203737
# Defective MTR causes methylmalonic aciduria and...            1.203737
#
#                                                     ER-/PR-/HER2+ qvalues
# RUNX1 regulates estrogen receptor mediated tran...              47.965007
# Activation of AMPK downstream of NMDARs                         33.302640
# Transcriptional Regulation by MECP2                             33.619616
# SLC-mediated transmembrane transport                            23.547715
# DAG and IP3 signaling                                           25.860778
# PLC beta mediated events                                        23.696661
# G-protein mediated events                                       23.062481
# Caspase-mediated cleavage of cytoskeletal proteins              33.147336
# TFAP2 (AP-2) family regulates transcription of ...              29.772001
# Cyclin D associated events in G1                                26.944196
# G1 Phase                                                        26.944196
# Estrogen-dependent nuclear events downstream of...              22.566871
# Ion channel transport                                           20.614268
# Reversible hydration of carbon dioxide                          26.381487
# Amino acid transport across the plasma membrane                 20.385489
# Transport of inorganic cations/anions and amino...              20.187482
# PKA-mediated phosphorylation of CREB                            18.156011
# Serine biosynthesis                                             33.388222
# Ca-dependent events                                             17.208603
# CaM pathway                                                     17.212173
# Calmodulin induced events                                       17.212173
# Cardiac conduction                                              18.363748
# ABC transporters in lipid homeostasis                           31.484219
# Post NMDA receptor activation events                            24.213526
# Activation of NMDA receptors and postsynaptic e...              24.697308
# Intraflagellar transport                                        18.904109
# Fatty acid metabolism                                           20.934591
# Signaling by ERBB4                                              20.132219
# Transport of bile salts and organic acids, meta...              14.436793
# MECP2 regulates neuronal receptors and channels                 29.296843
# ...                                                                   ...
# Regulation of commissural axon pathfinding by S...               0.371913
# Diseases associated with glycosaminoglycan meta...               0.537021
# Mitochondrial Fatty Acid Beta-Oxidation                          0.374472
# Proline catabolism                                              31.484219
# MECP2 regulates transcription of neuronal ligands                0.306285
# Post-translational protein phosphorylation                       0.870015
# Eicosanoid ligand-binding receptors                              0.534377
# SMAC, XIAP-regulated apoptotic response                          6.274772
# Biosynthesis of maresin-like SPMs                                0.632006
# Syndecan interactions                                            1.743503
# Cation-coupled Chloride cotransporters                           1.086582
# Synthesis of GDP-mannose                                         3.945805
# Defective B3GALT6 causes EDSP2 and SEMDJL1                       1.607728
# Golgi Associated Vesicle Biogenesis                              1.359001
# Membrane Trafficking                                             1.874135
# Organic anion transporters                                       4.809437
# Defective B4GALT7 causes EDS, progeroid type                     1.475166
# PI-3K cascade:FGFR1                                              0.307621
# Leukotriene receptors                                            0.595165
# Collagen degradation                                             0.878264
# Activated NTRK2 signals through PI3K                             5.336525
# Scavenging by Class H Receptors                                  0.599188
# G-protein activation                                             1.656784
# CYP2E1 reactions                                                 0.634136
# cGMP effects                                                     0.863347
# CS/DS degradation                                                0.996095
# Regulation of FZD by ubiquitination                              1.605132
# Chondroitin sulfate biosynthesis                                 0.505371
# Defective MTRR causes methylmalonic aciduria an...               1.443131
# Defective MTR causes methylmalonic aciduria and...               1.443131
#
# [2074 rows x 5 columns]

# %%
full_clusterframe.to_csv("../exp/receptor_qvalues.csv")
