# %%
import pandas as pd
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
gsea = pd.read_csv("GSEA_/gseapy.gsea.gene_set.report.csv", sep=",", index_col = 0)
gsea = gsea.iloc[:,:-4]
gsea.loc[gsea["fdr"] <= 0.001]
#gsea
# Out:
#                                                           es        nes  pval  \
# Term
# APC/C-mediated degradation of cell cycle protei... -0.732138  -3.606492   0.0
# Activation of ATR in response to replication st... -0.794665  -3.787954   0.0
# Assembly of the pre-replicative complex Homo sa... -0.759759  -3.796279   0.0
# Chromosome Maintenance Homo sapiens R-HSA-73886    -0.726851  -3.632762   0.0
# Class A/1 (Rhodopsin-like receptors) Homo sapie...  0.483698  10.422117   0.0
# DNA Replication Homo sapiens R-HSA-69306           -0.750996  -3.658488   0.0
# DNA Replication Pre-Initiation Homo sapiens R-H... -0.750451  -3.608788   0.0
# DNA strand elongation Homo sapiens R-HSA-69190     -0.848264  -3.805387   0.0
# Extracellular matrix organization Homo sapiens ...  0.607197  11.584581   0.0
# G alpha (i) signalling events Homo sapiens R-HS...  0.466559   8.810553   0.0
# G alpha (q) signalling events Homo sapiens R-HS...  0.529173   8.634166   0.0
# ...
