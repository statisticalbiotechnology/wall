# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
from matplotlib.pyplot import figure
figure(num=None, figsize=(15, 10), dpi=100, facecolor='w', edgecolor='k')
import pandas as pd
from scipy.stats import zscore, norm
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import truncnorm, norm
from scipy.optimize import fmin_slsqp
import qvalue as qv
# Out:
# <style>.container { width:100% !important; }</style>

# %%
pca_per_pathway = pd.read_csv('../data/pca_per_pathway.csv', index_col=0)

new_clinical_patient = pd.read_csv('../data/data_clinical_patient.txt', sep='\t', index_col=0).iloc[4:]
new_clinical_sample = pd.read_csv('../data/data_clinical_sample.txt', sep='\t', index_col=0).iloc[4:]
new_clinical = pd.concat([new_clinical_patient, new_clinical_sample.reindex(new_clinical_patient.index)], axis=1)
new_clinical['Triple Neg'] = new_clinical.apply(lambda row: True if ((row['ER Status'] == 'Negative') 
                                                                     and (row['PR Status'] == 'Negative') 
                                                                     and (row['HER2 Status'] == 'Negative')) else False, axis = 1)

new_clinical['ER-/PR-/HER2+'] = new_clinical.apply(lambda row: True if ((row['ER Status'] == 'Negative') 
                                                                     and (row['PR Status'] == 'Negative') 
                                                                     and (row['HER2 Status'] == 'Positive')) else False, axis = 1)

# %%
full_df = pd.concat([pca_per_pathway, new_clinical.reindex(pca_per_pathway.index)], axis=1)

# %%
from statsmodels.formula.api import ols
import statsmodels.api as sm
import qvalue as qv

clusterframes = {}

receptors = ['ER Status', 'PR Status', 'HER2 Status', 'Triple Neg']
for i in receptors:
    if type(i) == str:
        df_cluster = pd.DataFrame(index=pca_per_pathway.columns) 
        pvaluelist = []
        for pathway in df_cluster.index:
            results = ols("Q(pathway) ~ C(Q(i))", data=full_df).fit()
            table = sm.stats.anova_lm(results, typ=2)
            pvalue = table['PR(>F)'][0]
            pvaluelist.append(pvalue)
    
        df_cluster['p-values'] = pvaluelist
        qv.qvalues(df_cluster, 'p-values', 'qvalues')
        print(i)
        clusterframes[i] = df_cluster
# Out:
# ER Status
# PR Status
# HER2 Status
# Triple Neg

# %%
clusterframes['ER Status']
# Out:
#                                                          p-values  \
# RUNX1 regulates estrogen receptor mediated tran...   0.000000e+00
# Transcriptional Regulation by MECP2                  0.000000e+00
# SLC-mediated transmembrane transport                 0.000000e+00
# Cyclin D associated events in G1                    3.822443e-305
# G1 Phase                                            3.822574e-305
# ...                                                           ...
# PI-3K cascade:FGFR4                                  9.769136e-01
# CLEC7A/inflammasome pathway                          9.775655e-01
# Defective MTR causes methylmalonic aciduria and...   9.883994e-01
# Defective MTRR causes methylmalonic aciduria an...   9.884030e-01
# Cam-PDE 1 activation                                 9.984243e-01
#
#                                                           qvalues
# RUNX1 regulates estrogen receptor mediated tran...   0.000000e+00
# Transcriptional Regulation by MECP2                  0.000000e+00
# SLC-mediated transmembrane transport                 0.000000e+00
# Cyclin D associated events in G1                    1.585604e-302
# G1 Phase                                            1.585604e-302
# ...                                                           ...
# PI-3K cascade:FGFR4                                  9.788014e-01
# CLEC7A/inflammasome pathway                          9.789815e-01
# Defective MTR causes methylmalonic aciduria and...   9.888798e-01
# Defective MTRR causes methylmalonic aciduria an...   9.888798e-01
# Cam-PDE 1 activation                                 9.984243e-01
#
# [2074 rows x 2 columns]

# %%
significant_pathways = {}
def failures_of_null(cluster, my_xa, my_xb, iterations=10000):
    pvalues = clusterframes[cluster]['p-values'].tolist()
    pvalues = [1e-320 if x == 0.0 else x for x in pvalues]##p = 0 gives error so setting it to 1e-320
    pvalues = [0.999 if x == 1.0 else x for x in pvalues] ##pathways with p-val 1 gave error as range would be to inf
    pvalues = sorted(pvalues)
    z_scores = norm.ppf(pvalues)
    print(z_scores)
    xa = np.percentile(z_scores, my_xa)
    xb = np.percentile(z_scores, my_xb)
    print(f'Quantiles calculated: {xa}, {xb}')


    trunc_z = z_scores[z_scores>xa]
    trunc_z = trunc_z[trunc_z<xb]

    def func(p, r, xa, xb):
        return truncnorm.nnlf(p, r)

    def constraint(p, r, xa, xb):
        a, b, loc, scale = p
        return np.array([a*scale + loc - xa, b*scale + loc - xb])

    loc_guess = np.median(z_scores)
    scale_guess = np.std(z_scores)
    a_guess = (xa - loc_guess)/scale_guess
    b_guess = (xb - loc_guess)/scale_guess
    p0 = [a_guess, b_guess, loc_guess, scale_guess]

    par = fmin_slsqp(func, p0, f_eqcons=constraint, args=(trunc_z, xa, xb), iter=iterations)
    print(par)

    fig, ax = plt.subplots(1, 1, figsize=(15, 10))
    ax.hist(z_scores, bins=50, density=True)
    ax.plot(z_scores, truncnorm.pdf(z_scores, par[0], par[1], par[2], par[3]), 'r-', lw=5, alpha=0.6, label='truncnorm pdf')
    ax.plot(z_scores, norm.pdf(z_scores, par[2], par[3]), 'g-', lw=5, alpha=0.6, label='norm pdf')
    #ax.plot(z_scores, norm.sf(abs(z_scores-par[2]), 0, par[3]), 'y-', lw=5, alpha=0.6, label='norm sf')
    ax.legend(loc='best')
    plt.show()

    p_vals = norm.sf(abs(z_scores-par[2]), 0, par[3])

    plt.figure(figsize=(15, 10))
    plt.hist(p_vals, bins=30, density=True)
    plt.show()
    #print(pvalues[:10])
    print(p_vals[:20])
    sig_pathways = p_vals[p_vals < 0.001].size
    significant_pathways[cluster] = sig_pathways
    print(f'number of pathways with p < 0.001: {p_vals[p_vals < 0.001].size}')
    
    
    ##let's add to clusterframes
    clusterframes[cluster]['adjusted p-value'] = p_vals
    qv.qvalues(clusterframes[cluster], 'adjusted p-value', 'adjusted q-values')
    
    ##and log fold change
    clusterframes[cluster]['log adjusted p-value'] = -np.log10(clusterframes[cluster]['adjusted p-value'])
    clusterframes[cluster][f'{cluster} log adjusted q-value'] = -np.log10(clusterframes[cluster]['adjusted q-values'])

# %%
failures_of_null('ER Status', 57, 99.99)
# Out:
# [-38.26912534 -38.26912534 -38.26912534 ...   2.27010629   2.27022522
#    2.95257308]
# Quantiles calculated: -7.544187213178688, 2.811122370817394
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1949.308232957273
#             Iterations: 309
#             Function evaluations: 2448
#             Gradient evaluations: 309
# [-1.61329117  2.36076821 -3.34039257  2.60572593]
# [2.84116395e-41 2.84116395e-41 2.84116395e-41 3.59738919e-39
#  3.59740580e-39 1.51178613e-37 3.13496034e-37 1.10728735e-36
#  1.64292888e-36 2.20225231e-36 5.43684990e-36 1.02157951e-35
#  9.69034637e-35 2.41720204e-34 6.38902654e-34 6.36724560e-33
#  3.01234753e-32 3.13727554e-32 9.00968222e-32 9.33811254e-32]
# number of pathways with p < 0.001: 817

# %%
failures_of_null('PR Status', 60, 99)
# Out:
# [-28.90220919 -26.9032909  -23.64965628 ...   2.10681018   2.11164964
#    2.90697512]
# Quantiles calculated: -4.6108104692527245, 1.5516926755501301
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1417.39131737675
#             Iterations: 1618
#             Function evaluations: 13623
#             Gradient evaluations: 1618
# [-1.45388188  1.77388015 -1.83503221  1.90921855]
# [6.34958760e-46 1.10660376e-39 1.55132892e-30 2.27152518e-30
#  2.27156641e-30 2.81300597e-30 8.40755786e-30 1.58266660e-29
#  2.26419582e-28 2.26444154e-28 2.46341440e-28 2.77026045e-28
#  3.79186157e-28 4.94123898e-28 1.27679567e-27 1.85694704e-27
#  2.48868494e-27 2.96107912e-27 3.40279867e-27 2.87453287e-26]
# number of pathways with p < 0.001: 811

# %%
failures_of_null('HER2 Status', 20, 99.99)
# Out:
# [-21.16287283 -21.00340297 -18.10705278 ...   2.38382655   2.42612614
#    3.11935131]
# Quantiles calculated: -5.249682585901047, 2.975645734029999
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3204.4125198328275
#             Iterations: 88
#             Function evaluations: 680
#             Gradient evaluations: 88
# [-1.63617503  2.50507685 -1.99992207  1.98619368]
# [2.50429078e-22 5.46084334e-22 2.54044418e-16 7.08013943e-16
#  1.27309639e-14 3.14127092e-14 1.25500479e-13 4.09161258e-13
#  1.48862832e-10 2.56547192e-10 8.62011438e-10 9.61213908e-10
#  1.91932147e-08 2.82862109e-08 3.96582554e-08 5.32477982e-08
#  1.32527865e-07 1.99563677e-07 2.66027679e-07 4.04964239e-07]
# number of pathways with p < 0.001: 111

# %%
failures_of_null('Triple Neg', 55, 99.99)
# Out:
# [-37.47293133 -35.09328675 -34.55835369 ...   2.10102206   2.71782559
#    2.83164732]
# Quantiles calculated: -7.301652100708399, 2.808052078152175
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2039.1471530017716
#             Iterations: 160
#             Function evaluations: 1236
#             Gradient evaluations: 160
# [-1.23767046  2.22791965 -3.691161    2.91716673]
# [2.59212887e-31 2.52910422e-27 1.82085972e-26 3.94331518e-26
#  3.94334040e-26 3.86580490e-25 1.03298909e-24 7.71381481e-24
#  1.62287996e-23 2.41544695e-23 4.46585346e-23 4.95058667e-23
#  8.50567428e-23 1.10656636e-22 1.29635912e-22 1.44437968e-22
#  2.99788596e-22 3.72681918e-22 4.37550759e-22 5.13108572e-22]
# number of pathways with p < 0.001: 638

# %%
clusterframes['Triple Neg']
# Out:
#                                                          p-values  \
# SLC-mediated transmembrane transport                1.271331e-307
# Transport of bile salts and organic acids, meta...  4.266649e-270
# Sphingolipid metabolism                             5.338615e-262
# Cyclin D associated events in G1                    7.953021e-259
# G1 Phase                                            7.953502e-259
# ...                                                           ...
# Protein ubiquitination                               1.180126e-04
# Transcriptional regulation of granulopoiesis         1.169530e-04
# Late endosomal microautophagy                        1.156311e-04
# Unblocking of NMDA receptors, glutamate binding...   1.140050e-04
# Dermatan sulfate biosynthesis                        1.101018e-04
#
#                                                           qvalues  \
# SLC-mediated transmembrane transport                2.636740e-304
# Transport of bile salts and organic acids, meta...  4.424515e-267
# Sphingolipid metabolism                             3.690762e-259
# Cyclin D associated events in G1                    3.299113e-256
# G1 Phase                                            3.299113e-256
# ...                                                           ...
# Protein ubiquitination                               1.595555e-04
# Transcriptional regulation of granulopoiesis         1.582261e-04
# Late endosomal microautophagy                        1.565397e-04
# Unblocking of NMDA receptors, glutamate binding...   1.544391e-04
# Dermatan sulfate biosynthesis                        1.492491e-04
#
#                                                     adjusted p-value  \
# SLC-mediated transmembrane transport                    5.184258e-31
# Transport of bile salts and organic acids, meta...      5.058208e-27
# Sphingolipid metabolism                                 3.641719e-26
# Cyclin D associated events in G1                        7.886630e-26
# G1 Phase                                                7.886681e-26
# ...                                                              ...
# Protein ubiquitination                                  9.961173e-01
# Transcriptional regulation of granulopoiesis            9.967466e-01
# Late endosomal microautophagy                           9.975393e-01
# Unblocking of NMDA receptors, glutamate binding...      9.985262e-01
# Dermatan sulfate biosynthesis                           9.990500e-01
#
#                                                     adjusted q-values  \
# SLC-mediated transmembrane transport                     1.075215e-27
# Transport of bile salts and organic acids, meta...       5.245362e-24
# Sphingolipid metabolism                                  2.517642e-23
# Cyclin D associated events in G1                         3.271395e-23
# G1 Phase                                                 3.271395e-23
# ...                                                               ...
# Protein ubiquitination                                   9.980421e-01
# Transcriptional regulation of granulopoiesis             9.981905e-01
# Late endosomal microautophagy                            9.985022e-01
# Unblocking of NMDA receptors, glutamate binding...       9.990079e-01
# Dermatan sulfate biosynthesis                            9.990500e-01
#
#                                                     log adjusted p-value  \
# SLC-mediated transmembrane transport                           30.285313
# Transport of bile salts and organic acids, meta...             26.296003
# Sphingolipid metabolism                                        25.438694
# Cyclin D associated events in G1                               25.103109
# G1 Phase                                                       25.103106
# ...                                                                  ...
# Protein ubiquitination                                          0.001690
# Transcriptional regulation of granulopoiesis                    0.001415
# Late endosomal microautophagy                                   0.001070
# Unblocking of NMDA receptors, glutamate binding...              0.000641
# Dermatan sulfate biosynthesis                                   0.000413
#
#                                                     Triple Neg log adjusted q-value
# SLC-mediated transmembrane transport                                      26.968505
# Transport of bile salts and organic acids, meta...                        23.280225
# Sphingolipid metabolism                                                   22.599006
# Cyclin D associated events in G1                                          22.485267
# G1 Phase                                                                  22.485267
# ...                                                                             ...
# Protein ubiquitination                                                     0.000851
# Transcriptional regulation of granulopoiesis                               0.000787
# Late endosomal microautophagy                                              0.000651
# Unblocking of NMDA receptors, glutamate binding...                         0.000431
# Dermatan sulfate biosynthesis                                              0.000413
#
# [2074 rows x 6 columns]

# %%
adjusted_q_counts = {}
for cluster in clusterframes:
    columnshape = clusterframes[cluster][clusterframes[cluster]['adjusted q-values'] <= 0.001].shape[0]
    adjusted_q_counts[cluster] = columnshape
print(adjusted_q_counts)
full_df = pd.DataFrame({'Adjusted distribution pathways with q <= 10E-3': adjusted_q_counts})
ax = full_df.plot.bar(rot=0, figsize=(15, 10))
plt.show()
# Out:
# {'ER Status': 706, 'PR Status': 455, 'HER2 Status': 44, 'Triple Neg': 508}

# %%
full_clusterframe = pd.DataFrame(index=clusterframes['Triple Neg'].index)
full_clusterframe
for i in clusterframes:
    print(type(i))
    series = clusterframes[i][f'{i} log adjusted q-value']
    full_clusterframe = pd.concat([full_clusterframe, series.reindex(full_clusterframe.index)], axis=1)
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
full_clusterframe.to_csv('../exp/adjusted_distributions_receptors.csv')

# %%
import HTML
fclist = full_clusterframe['Triple Neg log adjusted q-value'].tolist()
fclist
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-29-3f9c661cbafb> in <module>
# ----> 1 import HTML
#       2 fclist = full_clusterframe['Triple Neg log adjusted q-value'].tolist()
#       3 fclist
#
# ModuleNotFoundError: No module named 'HTML'

# %%
def make_html_table(df, column, threshold=30):
    series = df[column]
    series = series.sort_values(ascending=False)
    series = series.iloc[:threshold]
    print(series)
    full_table = []
    full_table.append(series.index.to_list())
    full_table.append(series.tolist())
    print(full_table)
    print('<table> \n<tbody>')
    for i in range(0, len(full_table[0])):
        print(f'<tr><td>{full_table[0][i]}</td><td>{full_table[1][i]}</td></tr>')
    print('</tbody> \n</table>')
    
make_html_table(full_clusterframe, 'Triple Neg log adjusted q-value')
# Out:
# SLC-mediated transmembrane transport                                                                                     26.968505
# Transport of bile salts and organic acids, metal ions and amine compounds                                                23.280225
# Sphingolipid metabolism                                                                                                  22.599006
# Cyclin D associated events in G1                                                                                         22.485267
# G1 Phase                                                                                                                 22.485267
# Amino acid transport across the plasma membrane                                                                          21.573073
# Transcriptional Regulation by MECP2                                                                                      21.213164
# Synthesis of substrates in N-glycan biosythesis                                                                          20.397982
# G-protein mediated events                                                                                                20.126117
# PLC beta mediated events                                                                                                 19.999164
# Biosynthesis of the N-glycan precursor (dolichol lipid-linked oligosaccharide, LLO) and transfer to a nascent protein    19.773649
# Glycosphingolipid metabolism                                                                                             19.766686
# PKA-mediated phosphorylation of CREB                                                                                     19.566396
# TFAP2 (AP-2) family regulates transcription of growth factors and their receptors                                        19.484312
# Sialic acid metabolism                                                                                                   19.445527
# Ca-dependent events                                                                                                      19.426600
# RHO GTPases Activate Rhotekin and Rhophilins                                                                             19.135795
# RUNX1 regulates estrogen receptor mediated transcription                                                                 19.066095
# DAG and IP3 signaling                                                                                                    19.019886
# Synthesis of PC                                                                                                          18.980600
# CaM pathway                                                                                                              18.980600
# Calmodulin induced events                                                                                                18.980600
# Transport of inorganic cations/anions and amino acids/oligopeptides                                                      18.750053
# Vitamin C (ascorbate) metabolism                                                                                         18.419287
# RET signaling                                                                                                            18.284203
# Reversible hydration of carbon dioxide                                                                                   18.207611
# Evasion of Oxidative Stress Induced Senescence Due to p16INK4A Defects                                                   17.751846
# Evasion of Oncogene Induced Senescence Due to Defective p16INK4A binding to CDK4 and CDK6                                17.751846
# Evasion of Oxidative Stress Induced Senescence Due to Defective p16INK4A binding to CDK4 and CDK6                        17.751846
# Evasion of Oncogene Induced Senescence Due to p16INK4A Defects                                                           17.751846
# Name: Triple Neg log adjusted q-value, dtype: float64
# [['SLC-mediated transmembrane transport', 'Transport of bile salts and organic acids, metal ions and amine compounds', 'Sphingolipid metabolism', 'Cyclin D associated events in G1', 'G1 Phase', 'Amino acid transport across the plasma membrane', 'Transcriptional Regulation by MECP2', 'Synthesis of substrates in N-glycan biosythesis', 'G-protein mediated events', 'PLC beta mediated events', 'Biosynthesis of the N-glycan precursor (dolichol lipid-linked oligosaccharide, LLO) and transfer to a nascent protein', 'Glycosphingolipid metabolism', 'PKA-mediated phosphorylation of CREB', 'TFAP2 (AP-2) family regulates transcription of growth factors and their receptors', 'Sialic acid metabolism', 'Ca-dependent events', 'RHO GTPases Activate Rhotekin and Rhophilins', 'RUNX1 regulates estrogen receptor mediated transcription', 'DAG and IP3 signaling', 'Synthesis of PC', 'CaM pathway', 'Calmodulin induced events', 'Transport of inorganic cations/anions and amino acids/oligopeptides', 'Vitamin C (ascorbate) metabolism', 'RET signaling', 'Reversible hydration of carbon dioxide', 'Evasion of Oxidative Stress Induced Senescence Due to p16INK4A Defects', 'Evasion of Oncogene Induced Senescence Due to Defective p16INK4A binding to CDK4 and CDK6', 'Evasion of Oxidative Stress Induced Senescence Due to Defective p16INK4A binding to CDK4 and CDK6', 'Evasion of Oncogene Induced Senescence Due to p16INK4A Defects'], [26.968504663417722, 23.280224522306916, 22.599006018767778, 22.485266988974303, 22.485266988974303, 21.57307257024035, 21.213163557354118, 20.39798203113442, 20.126117363535794, 19.999163748607273, 19.773649469216384, 19.766685830566228, 19.566395856821718, 19.484311823803218, 19.44552718267005, 19.42659986527454, 19.13579506555797, 19.066095435679348, 19.019886412171648, 18.980599912377713, 18.980599912377713, 18.980599912377713, 18.750052952383392, 18.419286671617815, 18.284203345652035, 18.20761069258882, 17.751845710245966, 17.751845710245966, 17.751845710245966, 17.751845710245966]]
# <table>
# <tbody>
# <tr><td>SLC-mediated transmembrane transport</td><td>26.968504663417722</td></tr>
# <tr><td>Transport of bile salts and organic acids, metal ions and amine compounds</td><td>23.280224522306916</td></tr>
# <tr><td>Sphingolipid metabolism</td><td>22.599006018767778</td></tr>
# <tr><td>Cyclin D associated events in G1</td><td>22.485266988974303</td></tr>
# <tr><td>G1 Phase</td><td>22.485266988974303</td></tr>
# <tr><td>Amino acid transport across the plasma membrane</td><td>21.57307257024035</td></tr>
# <tr><td>Transcriptional Regulation by MECP2</td><td>21.213163557354118</td></tr>
# <tr><td>Synthesis of substrates in N-glycan biosythesis</td><td>20.39798203113442</td></tr>
# <tr><td>G-protein mediated events</td><td>20.126117363535794</td></tr>
# <tr><td>PLC beta mediated events</td><td>19.999163748607273</td></tr>
# <tr><td>Biosynthesis of the N-glycan precursor (dolichol lipid-linked oligosaccharide, LLO) and transfer to a nascent protein</td><td>19.773649469216384</td></tr>
# <tr><td>Glycosphingolipid metabolism</td><td>19.766685830566228</td></tr>
# <tr><td>PKA-mediated phosphorylation of CREB</td><td>19.566395856821718</td></tr>
# <tr><td>TFAP2 (AP-2) family regulates transcription of growth factors and their receptors</td><td>19.484311823803218</td></tr>
# <tr><td>Sialic acid metabolism</td><td>19.44552718267005</td></tr>
# <tr><td>Ca-dependent events</td><td>19.42659986527454</td></tr>
# <tr><td>RHO GTPases Activate Rhotekin and Rhophilins</td><td>19.13579506555797</td></tr>
# <tr><td>RUNX1 regulates estrogen receptor mediated transcription</td><td>19.066095435679348</td></tr>
# <tr><td>DAG and IP3 signaling</td><td>19.019886412171648</td></tr>
# <tr><td>Synthesis of PC</td><td>18.980599912377713</td></tr>
# <tr><td>CaM pathway</td><td>18.980599912377713</td></tr>
# <tr><td>Calmodulin induced events</td><td>18.980599912377713</td></tr>
# <tr><td>Transport of inorganic cations/anions and amino acids/oligopeptides</td><td>18.750052952383392</td></tr>
# <tr><td>Vitamin C (ascorbate) metabolism</td><td>18.419286671617815</td></tr>
# <tr><td>RET signaling</td><td>18.284203345652035</td></tr>
# <tr><td>Reversible hydration of carbon dioxide</td><td>18.20761069258882</td></tr>
# <tr><td>Evasion of Oxidative Stress Induced Senescence Due to p16INK4A Defects</td><td>17.751845710245966</td></tr>
# <tr><td>Evasion of Oncogene Induced Senescence Due to Defective p16INK4A binding to CDK4 and CDK6</td><td>17.751845710245966</td></tr>
# <tr><td>Evasion of Oxidative Stress Induced Senescence Due to Defective p16INK4A binding to CDK4 and CDK6</td><td>17.751845710245966</td></tr>
# <tr><td>Evasion of Oncogene Induced Senescence Due to p16INK4A Defects</td><td>17.751845710245966</td></tr>
# </tbody>
# </table>
