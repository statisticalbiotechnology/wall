# %%
import pandas as pd
import numpy as np
import qvalue as qv
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
clust_1 = pd.read_csv('GSEA_/1/gseapy.gsea.gene_set.report.csv').iloc[:,:-3]

# %%
clust_1[clust_1['fdr'] < 0.001].sort_values(by="fdr")
# Out:
#                                                   Term        es       nes  \
# 0    APC/C-mediated degradation of cell cycle prote... -0.729523 -4.198773
# 23       Mitotic Prometaphase Homo sapiens R-HSA-68877 -0.719293 -4.133497
# 24       Nucleosome assembly Homo sapiens R-HSA-774815 -0.791215 -4.087886
# 25   Processing of DNA double-strand break ends Hom... -0.708440 -4.110347
# 26   Regulation of APC/C activators between G1/S an... -0.712871 -4.090113
# ..                                                 ...       ...       ...
# 121      Degradation of DVL Homo sapiens R-HSA-4641258 -0.652248 -3.524083
# 122       Cell Cycle, Mitotic Homo sapiens R-HSA-69278 -0.633657 -3.521760
# 123               Mitophagy Homo sapiens R-HSA-5205647 -0.712574 -3.517384
# 124  E2F mediated regulation of DNA replication Hom... -0.709870 -3.515238
# 125  RNA Polymerase II Transcription Homo sapiens R... -0.605843 -3.509575
#
#          pval       fdr  geneset_size
# 0    0.000000  0.000000            85
# 23   0.000000  0.000000           107
# 24   0.000000  0.000000            52
# 25   0.000000  0.000000            81
# 26   0.000000  0.000000            79
# ..        ...       ...           ...
# 121  0.000000  0.000715            56
# 122  0.000000  0.000725           462
# 123  0.001848  0.000748            22
# 124  0.000000  0.000779            33
# 125  0.000000  0.000816           124
#
# [126 rows x 6 columns]

# %%
clust_1 = pd.read_csv('GSEA_/1/gseapy.gsea.gene_set.report.csv').iloc[:,:-3]

newlist = []
for i in clust_1['Term'].iteritems():
    i = i[1].split(" ")[-1:]
    newi = " ".join(i)
    newlist.append(newi)
new_series = pd.Series(newlist)
clust_1['Term'].update(new_series)
clust_1 = clust_1.set_index('Term')

# %%
clusternames = ['1', "2", "3", "4ER+", "4ER-", "5", "6", "7", "8", "9", "10"]

gsea_frames = {}
for cluster in clusternames:
    df = pd.read_csv(f"GSEA_/{cluster}/gseapy.gsea.gene_set.report.csv").iloc[:,:-3]
    #qv.qvalues(df, 'pval', f'cluster {cluster} q-value')
    #df[f'cluster {cluster} q-value'] = inf if x <= 0.0 else -np.log10(x) for x in df[f'cluster {cluster} q-value']
    print(df['fdr'].dtypes)
    df['fdr'] = df.apply(lambda row: 5.0 if (row['fdr'] == 0.0) else -np.log10(row['fdr']), axis=1)
    newlist = []
    for row in df['Term'].iteritems():
        row = row[1].split(" ")[:-3]
        newrow = " ".join(row)
        newlist.append(newrow)

    new_series = pd.Series(newlist)
    df['Term'].update(new_series)
    df = df.set_index('Term')
    df = df.loc[~df.index.duplicated(keep='first')]
    gsea_frames[cluster] = df
# Out:
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64

# %%
pathway_ID = pd.read_csv("../data/ReactomePathways.txt", sep="\t", index_col=0, header=None, names=['ID', 'Name', 'Species'])

for clust in gsea_frames:
        df = gsea_frames[clust]
        new_index = {}
        for i in df.index:
            if i in pathway_ID.index:
                full_name = pathway_ID.loc[i, 'Name']
                print(full_name)

# %%
gsea_frames['1']
# Out:
#                                                           es       nes  \
# Term
# APC/C-mediated degradation of cell cycle proteins  -0.729523 -4.198773
# APC/C:Cdh1 mediated degradation of Cdc20 and ot... -0.704414 -4.049305
# AUF1 (hnRNP D0) binds and destabilizes mRNA        -0.712956 -3.979519
# Activation of APC/C and APC/C:Cdc20 mediated de... -0.719178 -4.222743
# Assembly of the pre-replicative complex            -0.709862 -3.931598
# ...                                                      ...       ...
# Defective CSF2RB causes pulmonary surfactant me... -0.258043 -1.002278
# Glucocorticoid biosynthesis                        -0.249310 -0.979135
# CYP2E1 reactions                                   -0.242760 -0.980891
# Bile salt and organic anion SLC transporters       -0.209022 -0.930798
# Olfactory Signaling Pathway                        -0.145996 -0.856863
#
#                                                         pval       fdr  \
# Term
# APC/C-mediated degradation of cell cycle proteins   0.000000  5.000000
# APC/C:Cdh1 mediated degradation of Cdc20 and ot...  0.000000  5.000000
# AUF1 (hnRNP D0) binds and destabilizes mRNA         0.000000  5.000000
# Activation of APC/C and APC/C:Cdc20 mediated de...  0.000000  5.000000
# Assembly of the pre-replicative complex             0.000000  5.000000
# ...                                                      ...       ...
# Defective CSF2RB causes pulmonary surfactant me...  0.966229  0.009850
# Glucocorticoid biosynthesis                         0.971857  0.008680
# CYP2E1 reactions                                    0.945133  0.008297
# Bile salt and organic anion SLC transporters        0.981917  0.005731
# Olfactory Signaling Pathway                         1.000000  0.002971
#
#                                                     geneset_size
# Term
# APC/C-mediated degradation of cell cycle proteins             85
# APC/C:Cdh1 mediated degradation of Cdc20 and ot...            71
# AUF1 (hnRNP D0) binds and destabilizes mRNA                   54
# Activation of APC/C and APC/C:Cdc20 mediated de...            75
# Assembly of the pre-replicative complex                       67
# ...                                                          ...
# Defective CSF2RB causes pulmonary surfactant me...             8
# Glucocorticoid biosynthesis                                    9
# CYP2E1 reactions                                              11
# Bile salt and organic anion SLC transporters                  14
# Olfactory Signaling Pathway                                  418
#
# [1528 rows x 5 columns]

# %%
gsea_df = pd.DataFrame(index= gsea_frames['1'].index)
for i in gsea_frames:
    gsea_df[i] = gsea_frames[i][f'fdr']

# %%
gsea_frames['1'].index.duplicated
#gsea_frames['1'].index
# Out:
# <bound method Index.duplicated of Index(['APC/C-mediated degradation of cell cycle proteins',
#        'APC/C:Cdh1 mediated degradation of Cdc20 and other APC/C:Cdh1 targeted proteins in late mitosis/early G1',
#        'AUF1 (hnRNP D0) binds and destabilizes mRNA',
#        'Activation of APC/C and APC/C:Cdc20 mediated degradation of mitotic proteins',
#        'Assembly of the pre-replicative complex', 'Cell Cycle Checkpoints',
#        'Chromosome Maintenance',
#        'Cyclin A:Cdk2-associated events at S phase entry',
#        'Cyclin E associated events during G1/S transition',
#        'Degradation of AXIN',
#        ...
#        'Diseases of carbohydrate metabolism',
#        'FGFR3b ligand binding and activation',
#        'Highly sodium permeable acetylcholine nicotinic receptors',
#        'Class C/3 (Metabotropic glutamate/pheromone receptors)',
#        'Relaxin receptors',
#        'Defective CSF2RB causes pulmonary surfactant metabolism dysfunction 5 (SMDP5)',
#        'Glucocorticoid biosynthesis', 'CYP2E1 reactions',
#        'Bile salt and organic anion SLC transporters',
#        'Olfactory Signaling Pathway'],
#       dtype='object', name='Term', length=1528)>

# %%
gsea_df.sort_values(by='9', ascending = False).iloc[:50,:]
# Out:
#                                                            1         2  \
# Term
# Signal Transduction                                 5.000000  0.373340
# DNA strand elongation                               4.703125  3.232806
# Activation of NIMA Kinases NEK9, NEK6, NEK7         1.875547  0.342513
# DNA Replication                                     4.756371  2.709927
# Unwinding of DNA                                    3.282478  1.093933
# SLBP Dependent Processing of Replication-Depend...  2.392234  0.691255
# Activation of the pre-replicative complex           4.545517  1.991149
# Resolution of Sister Chromatid Cohesion             5.000000  2.148485
# Polo-like kinase mediated events                    3.871963  1.828706
# Mitotic Prometaphase                                5.000000  2.776874
# The role of GTSE1 in G2/M progression after G2 ...  5.000000  0.907838
# G1/S Transition                                     5.000000  2.977533
# Synthesis of DNA                                    5.000000  3.174814
# S Phase                                             5.000000  3.187048
# Chromosome Maintenance                              5.000000  5.000000
# G2/M Checkpoints                                    5.000000  1.938688
# Mitotic Metaphase and Anaphase                      5.000000  2.126186
# Activation of ATR in response to replication st...  4.076796  2.135896
# mRNA Splicing - Minor Pathway                       4.449737  0.564240
# M/G1 Transition                                     5.000000  1.073043
# G0 and Early G1                                     4.119548  0.687166
# Regulation of DNA replication                       5.000000  1.070039
# Golgi Cisternae Pericentriolar Stack Reorganiza...  2.857842  0.691361
# Pausing and recovery of Tat-mediated HIV elonga...  4.602660  0.109435
# Mitochondrial translation elongation                5.000000  0.896040
# Assembly of the pre-replicative complex             5.000000  0.806890
# Mitotic Anaphase                                    5.000000  2.135253
# Removal of licensing factors from origins           5.000000  1.368179
# Mitochondrial translation                           4.693580  0.875550
# Phosphorylation of Emi1                             2.948920  0.919833
# Metabolism of non-coding RNA                        2.597130  1.734834
# Cyclin B2 mediated events                           2.464760  0.615431
# DNA Replication Pre-Initiation                      4.114347  1.424488
# Orc1 removal from chromatin                         4.683820  1.294846
# SLBP independent Processing of Histone Pre-mRNAs    2.692115  0.465831
# Cyclin A/B1 associated events during G2/M trans...  4.558881  2.144079
# Purine ribonucleoside monophosphate biosynthesis    0.607251  0.312476
# Chk1/Chk2(Cds1) mediated inactivation of Cyclin...  2.177322  0.637801
# APC/C-mediated degradation of cell cycle proteins   5.000000  1.369408
# Separation of Sister Chromatids                     5.000000  2.025408
# Mitotic G1-G1/S phases                              4.071776  2.394657
# Mitochondrial translation termination               5.000000  0.748718
# Activation of APC/C and APC/C:Cdc20 mediated de...  5.000000  1.292961
# Switching of origins to a post-replicative state    5.000000  1.369781
# tRNA processing                                     2.565118  0.533605
# Mitochondrial translation initiation                5.000000  0.896074
# Processing of Capped Intronless Pre-mRNA            1.821097  0.280193
# Telomere Maintenance                                5.000000  3.329716
# snRNP Assembly                                      2.539187  1.929850
# Regulation of mitotic cell cycle                    5.000000  1.728094
#
#                                                            3      4ER+  \
# Term
# Signal Transduction                                 0.143460  5.000000
# DNA strand elongation                               5.000000  5.000000
# Activation of NIMA Kinases NEK9, NEK6, NEK7         2.097302  2.635653
# DNA Replication                                     5.000000  5.000000
# Unwinding of DNA                                    5.000000  5.000000
# SLBP Dependent Processing of Replication-Depend...  2.405999  4.680449
# Activation of the pre-replicative complex           5.000000  5.000000
# Resolution of Sister Chromatid Cohesion             5.000000  5.000000
# Polo-like kinase mediated events                    3.991639  5.000000
# Mitotic Prometaphase                                4.433999  5.000000
# The role of GTSE1 in G2/M progression after G2 ...  3.453104  4.948479
# G1/S Transition                                     5.000000  5.000000
# Synthesis of DNA                                    5.000000  5.000000
# S Phase                                             5.000000  5.000000
# Chromosome Maintenance                              5.000000  5.000000
# G2/M Checkpoints                                    5.000000  5.000000
# Mitotic Metaphase and Anaphase                      3.720490  5.000000
# Activation of ATR in response to replication st...  5.000000  5.000000
# mRNA Splicing - Minor Pathway                       1.876710  3.920450
# M/G1 Transition                                     5.000000  5.000000
# G0 and Early G1                                     5.000000  3.359921
# Regulation of DNA replication                       4.449793  5.000000
# Golgi Cisternae Pericentriolar Stack Reorganiza...  1.414465  2.407333
# Pausing and recovery of Tat-mediated HIV elonga...  1.759091  2.255009
# Mitochondrial translation elongation                1.476143  5.000000
# Assembly of the pre-replicative complex             4.034043  5.000000
# Mitotic Anaphase                                    3.566906  5.000000
# Removal of licensing factors from origins           4.044028  5.000000
# Mitochondrial translation                           1.262839  5.000000
# Phosphorylation of Emi1                             2.204280  3.226462
# Metabolism of non-coding RNA                        3.443327  5.000000
# Cyclin B2 mediated events                           2.813579  2.022107
# DNA Replication Pre-Initiation                      5.000000  5.000000
# Orc1 removal from chromatin                         4.023824  5.000000
# SLBP independent Processing of Histone Pre-mRNAs    2.142573  2.706377
# Cyclin A/B1 associated events during G2/M trans...  3.540454  4.685713
# Purine ribonucleoside monophosphate biosynthesis    2.163320  2.349177
# Chk1/Chk2(Cds1) mediated inactivation of Cyclin...  3.091779  2.399809
# APC/C-mediated degradation of cell cycle proteins   3.582418  5.000000
# Separation of Sister Chromatids                     3.535614  5.000000
# Mitotic G1-G1/S phases                              3.980358  3.631937
# Mitochondrial translation termination               1.355305  5.000000
# Activation of APC/C and APC/C:Cdc20 mediated de...  3.521149  4.942726
# Switching of origins to a post-replicative state    3.550337  5.000000
# tRNA processing                                     3.393065  5.000000
# Mitochondrial translation initiation                1.283556  5.000000
# Processing of Capped Intronless Pre-mRNA            2.504215  3.929000
# Telomere Maintenance                                3.968777  2.703149
# snRNP Assembly                                      3.956877  5.000000
# Regulation of mitotic cell cycle                    3.557516  5.000000
#
#                                                         4ER-         5  \
# Term
# Signal Transduction                                 5.000000  5.000000
# DNA strand elongation                               1.986246  1.584886
# Activation of NIMA Kinases NEK9, NEK6, NEK7         0.309608  1.708824
# DNA Replication                                     1.484251  3.738809
# Unwinding of DNA                                    0.307366  2.093283
# SLBP Dependent Processing of Replication-Depend...  0.904926  0.910706
# Activation of the pre-replicative complex           1.518510  1.918221
# Resolution of Sister Chromatid Cohesion             2.285706  2.935441
# Polo-like kinase mediated events                    1.458139  1.950898
# Mitotic Prometaphase                                1.988056  2.673416
# The role of GTSE1 in G2/M progression after G2 ...  0.748352  3.540441
# G1/S Transition                                     1.707514  3.074601
# Synthesis of DNA                                    1.462462  3.708846
# S Phase                                             2.192284  3.065393
# Chromosome Maintenance                              2.486993  1.422536
# G2/M Checkpoints                                    1.706426  5.000000
# Mitotic Metaphase and Anaphase                      1.698052  3.562718
# Activation of ATR in response to replication st...  1.511781  2.091249
# mRNA Splicing - Minor Pathway                       3.049550  0.419041
# M/G1 Transition                                     0.996011  3.942929
# G0 and Early G1                                     0.702632  1.392468
# Regulation of DNA replication                       0.854611  3.604111
# Golgi Cisternae Pericentriolar Stack Reorganiza...  0.940519  1.585648
# Pausing and recovery of Tat-mediated HIV elonga...  1.382832  0.123629
# Mitochondrial translation elongation                5.000000  0.937597
# Assembly of the pre-replicative complex             0.784811  5.000000
# Mitotic Anaphase                                    1.656767  3.034444
# Removal of licensing factors from origins           1.075225  3.676661
# Mitochondrial translation                           3.725039  0.942126
# Phosphorylation of Emi1                             1.063372  1.141211
# Metabolism of non-coding RNA                        2.925954  0.314506
# Cyclin B2 mediated events                           0.217537  1.438605
# DNA Replication Pre-Initiation                      0.968559  5.000000
# Orc1 removal from chromatin                         0.875660  2.981847
# SLBP independent Processing of Histone Pre-mRNAs    1.134839  1.217790
# Cyclin A/B1 associated events during G2/M trans...  2.345292  1.513395
# Purine ribonucleoside monophosphate biosynthesis    0.922142  0.330159
# Chk1/Chk2(Cds1) mediated inactivation of Cyclin...  2.170158  1.993110
# APC/C-mediated degradation of cell cycle proteins   1.352305  2.789962
# Separation of Sister Chromatids                     1.673537  3.583907
# Mitotic G1-G1/S phases                              1.080403  3.793167
# Mitochondrial translation termination               5.000000  1.470268
# Activation of APC/C and APC/C:Cdc20 mediated de...  1.127023  3.126989
# Switching of origins to a post-replicative state    0.893740  3.766838
# tRNA processing                                     2.169088  1.224928
# Mitochondrial translation initiation                5.000000  1.114059
# Processing of Capped Intronless Pre-mRNA            1.462192  0.837651
# Telomere Maintenance                                2.384567  0.233957
# snRNP Assembly                                      2.845613  0.459956
# Regulation of mitotic cell cycle                    1.459309  3.110420
#
#                                                            6         7  \
# Term
# Signal Transduction                                 0.480076  1.997777
# DNA strand elongation                               1.747955  3.284556
# Activation of NIMA Kinases NEK9, NEK6, NEK7         0.245008  1.413484
# DNA Replication                                     1.938120  5.000000
# Unwinding of DNA                                    1.518100  3.336558
# SLBP Dependent Processing of Replication-Depend...  0.380571  0.818192
# Activation of the pre-replicative complex           1.238261  3.343959
# Resolution of Sister Chromatid Cohesion             2.339875  4.267571
# Polo-like kinase mediated events                    2.278130  2.835892
# Mitotic Prometaphase                                3.787033  5.000000
# The role of GTSE1 in G2/M progression after G2 ...  1.729390  3.280500
# G1/S Transition                                     2.698897  3.733411
# Synthesis of DNA                                    1.902804  5.000000
# S Phase                                             3.720086  4.214325
# Chromosome Maintenance                              3.640905  2.476100
# G2/M Checkpoints                                    2.187587  5.000000
# Mitotic Metaphase and Anaphase                      2.208203  5.000000
# Activation of ATR in response to replication st...  1.241222  3.541807
# mRNA Splicing - Minor Pathway                       1.738494  0.977523
# M/G1 Transition                                     1.359872  5.000000
# G0 and Early G1                                     1.745744  2.405003
# Regulation of DNA replication                       1.374549  3.687230
# Golgi Cisternae Pericentriolar Stack Reorganiza...  0.552888  0.261841
# Pausing and recovery of Tat-mediated HIV elonga...  1.732342  0.142712
# Mitochondrial translation elongation                1.617575  0.907510
# Assembly of the pre-replicative complex             1.187129  4.174817
# Mitotic Anaphase                                    2.288723  5.000000
# Removal of licensing factors from origins           1.857614  3.852597
# Mitochondrial translation                           1.371312  0.637807
# Phosphorylation of Emi1                             1.101786  1.195188
# Metabolism of non-coding RNA                        1.006308  5.000000
# Cyclin B2 mediated events                           1.024510  1.556325
# DNA Replication Pre-Initiation                      1.313879  5.000000
# Orc1 removal from chromatin                         1.381308  3.505810
# SLBP independent Processing of Histone Pre-mRNAs    0.415536  0.948876
# Cyclin A/B1 associated events during G2/M trans...  1.370630  1.646551
# Purine ribonucleoside monophosphate biosynthesis    0.296145  0.419324
# Chk1/Chk2(Cds1) mediated inactivation of Cyclin...  1.382922  2.564829
# APC/C-mediated degradation of cell cycle proteins   2.221776  2.919544
# Separation of Sister Chromatids                     3.543995  5.000000
# Mitotic G1-G1/S phases                              2.062229  4.195020
# Mitochondrial translation termination               1.162238  0.848187
# Activation of APC/C and APC/C:Cdc20 mediated de...  1.382736  3.943678
# Switching of origins to a post-replicative state    1.628232  3.866838
# tRNA processing                                     1.372071  3.535480
# Mitochondrial translation initiation                1.711783  0.665399
# Processing of Capped Intronless Pre-mRNA            0.483666  0.758281
# Telomere Maintenance                                2.663181  1.952549
# snRNP Assembly                                      0.937779  3.597325
# Regulation of mitotic cell cycle                    1.742779  2.460318
#
#                                                            8         9  \
# Term
# Signal Transduction                                 1.181154  5.000000
# DNA strand elongation                               1.825621  2.771394
# Activation of NIMA Kinases NEK9, NEK6, NEK7         0.913063  2.595302
# DNA Replication                                     4.038981  2.560540
# Unwinding of DNA                                    2.707988  2.537310
# SLBP Dependent Processing of Replication-Depend...  0.475765  2.528356
# Activation of the pre-replicative complex           2.077963  2.488847
# Resolution of Sister Chromatid Cohesion             1.590959  2.470364
# Polo-like kinase mediated events                    1.195995  2.449174
# Mitotic Prometaphase                                1.952541  2.356420
# The role of GTSE1 in G2/M progression after G2 ...  2.987829  2.349320
# G1/S Transition                                     3.330251  2.344070
# Synthesis of DNA                                    3.531897  2.336470
# S Phase                                             3.976833  2.335109
# Chromosome Maintenance                              2.254581  2.334144
# G2/M Checkpoints                                    2.994562  2.332061
# Mitotic Metaphase and Anaphase                      2.602393  2.323375
# Activation of ATR in response to replication st...  2.574094  2.314476
# mRNA Splicing - Minor Pathway                       0.376933  2.312756
# M/G1 Transition                                     3.304539  2.307237
# G0 and Early G1                                     2.444813  2.300903
# Regulation of DNA replication                       3.499712  2.299125
# Golgi Cisternae Pericentriolar Stack Reorganiza...  0.546232  2.294272
# Pausing and recovery of Tat-mediated HIV elonga...  0.505354  2.284932
# Mitochondrial translation elongation                0.207768  2.272874
# Assembly of the pre-replicative complex             4.118162  2.267943
# Mitotic Anaphase                                    2.101182  2.267443
# Removal of licensing factors from origins           3.321528  2.266244
# Mitochondrial translation                           0.190740  2.262980
# Phosphorylation of Emi1                             1.202929  2.262383
# Metabolism of non-coding RNA                        0.303023  2.259510
# Cyclin B2 mediated events                           1.238777  2.258434
# DNA Replication Pre-Initiation                      4.163920  2.258275
# Orc1 removal from chromatin                         4.093339  2.256948
# SLBP independent Processing of Histone Pre-mRNAs    0.481495  2.253978
# Cyclin A/B1 associated events during G2/M trans...  1.335189  2.252880
# Purine ribonucleoside monophosphate biosynthesis    0.065628  2.239560
# Chk1/Chk2(Cds1) mediated inactivation of Cyclin...  1.484486  2.191919
# APC/C-mediated degradation of cell cycle proteins   2.842686  2.180916
# Separation of Sister Chromatids                     2.552100  2.094700
# Mitotic G1-G1/S phases                              5.000000  2.092717
# Mitochondrial translation termination               0.143295  2.091779
# Activation of APC/C and APC/C:Cdc20 mediated de...  2.415732  2.091159
# Switching of origins to a post-replicative state    3.482679  2.088423
# tRNA processing                                     0.247160  2.086799
# Mitochondrial translation initiation                0.144829  2.081831
# Processing of Capped Intronless Pre-mRNA            0.252278  2.075613
# Telomere Maintenance                                0.637775  2.065958
# snRNP Assembly                                      0.294289  2.055564
# Regulation of mitotic cell cycle                    2.857357  2.031031
#
#                                                           10
# Term
# Signal Transduction                                 0.204819
# DNA strand elongation                               5.000000
# Activation of NIMA Kinases NEK9, NEK6, NEK7         1.485726
# DNA Replication                                     5.000000
# Unwinding of DNA                                    3.706544
# SLBP Dependent Processing of Replication-Depend...  1.226538
# Activation of the pre-replicative complex           5.000000
# Resolution of Sister Chromatid Cohesion             5.000000
# Polo-like kinase mediated events                    2.620472
# Mitotic Prometaphase                                5.000000
# The role of GTSE1 in G2/M progression after G2 ...  3.686279
# G1/S Transition                                     3.786333
# Synthesis of DNA                                    5.000000
# S Phase                                             3.590594
# Chromosome Maintenance                              3.717060
# G2/M Checkpoints                                    5.000000
# Mitotic Metaphase and Anaphase                      5.000000
# Activation of ATR in response to replication st...  5.000000
# mRNA Splicing - Minor Pathway                       1.734564
# M/G1 Transition                                     5.000000
# G0 and Early G1                                     3.673375
# Regulation of DNA replication                       5.000000
# Golgi Cisternae Pericentriolar Stack Reorganiza...  0.532988
# Pausing and recovery of Tat-mediated HIV elonga...  0.581416
# Mitochondrial translation elongation                0.930945
# Assembly of the pre-replicative complex             5.000000
# Mitotic Anaphase                                    5.000000
# Removal of licensing factors from origins           5.000000
# Mitochondrial translation                           1.398226
# Phosphorylation of Emi1                             1.587108
# Metabolism of non-coding RNA                        5.000000
# Cyclin B2 mediated events                           1.781384
# DNA Replication Pre-Initiation                      5.000000
# Orc1 removal from chromatin                         4.517487
# SLBP independent Processing of Histone Pre-mRNAs    1.575345
# Cyclin A/B1 associated events during G2/M trans...  2.045970
# Purine ribonucleoside monophosphate biosynthesis    1.187525
# Chk1/Chk2(Cds1) mediated inactivation of Cyclin...  2.050916
# APC/C-mediated degradation of cell cycle proteins   3.477720
# Separation of Sister Chromatids                     5.000000
# Mitotic G1-G1/S phases                              5.000000
# Mitochondrial translation termination               1.169841
# Activation of APC/C and APC/C:Cdc20 mediated de...  3.693579
# Switching of origins to a post-replicative state    4.506492
# tRNA processing                                     3.709373
# Mitochondrial translation initiation                0.816428
# Processing of Capped Intronless Pre-mRNA            1.892319
# Telomere Maintenance                                2.229341
# snRNP Assembly                                      5.000000
# Regulation of mitotic cell cycle                    3.675095

# %%
gsea_df.to_csv('../exp/GSEA_qvalues.csv')
